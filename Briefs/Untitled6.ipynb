# %%
import pandas as pd

filename ='Users\Owner\PycharmProjects\CSC3130\WebProject_KyleMcLean\Briefs\2017-02-18CraigslistBriefs.json'
#filename = 'C:\Users\username\pathToFile\fileName.json'
#filename = 'fileName.json'
data = pd.read_json('2017-02-18.RentBriefs.json')

# %%
data
# Out:
#                 location           phone  price    size
# 0   (Downtown Nashville)  (844) 538-9754  $1399   1 Bed
# 1   (Historic Edgefield)  (844) 793-7781  $2000  2 Beds
# 2   (Cumberland Gardens)  (844) 887-7125   $850  2 Beds
# 3             (East End)  (877) 432-6013  $1500  2 Beds
# 4        (West End Park)  (844) 711-6208  $1195   1 Bed
# 5          (Green Hills)  (888) 923-3149  $1100   1 Bed
# 6    (Glencliff Estates)  (888) 630-1984  $1650  3 Beds
# 7                   None  (844) 509-3762  $2395  4 Beds
# 8      (Talbot's Corner)  (844) 320-2437  $1645  3 Beds
# 9                   None  (844) 783-5359  $1800  3 Beds
# 10              (Radnor)  (844) 610-7947  $1250  3 Beds
# 11          (River Glen)  (844) 865-5196  $1450  3 Beds
# 12                  None  (844) 783-5368  $1049  2 Beds
# 13                  None  (855) 233-2803  $1575  3 Beds
# 14   (Bellshire Terrace)  (844) 865-5197  $1395  3 Beds
# 15    (Whispering Hills)  (844) 585-1387  $2000  3 Beds
# ...

# %%
data2 = pd.read_json('2017-02-18.CraigslsitBriefs.json')

# %%
data2
# Out:
#                                              location       price        size
# 0     (159 Mansker Park Dr, Hendersonville, TN 37075)       $1870  Not listed
# 1                                    (900 19th Ave S)       $1375  Not listed
# 2                                         (Nashville)        $900  Not listed
# 3                                           (Oakland)        $950  Not listed
# 4                                       (Spring Hill)       $1800         3br
# 5                                (Downtown Nashville)       $2000  Not listed
# 6                                      (Murfreesboro)       $1030  Not listed
# 7                                         (Nashville)        $905  Not listed
# 8                      (108 Thompson Ln Nashville TN)        $900  Not listed
# 9                                         (Grassland)       $3000  Not listed
# 10                                    (Nashville, TN)       $1490  Not listed
# ...

# %%
#I'm interested in finding the average overall price, the number of listings for each region, and the average price for bedrooms

# %%
#For my project I am going to create a bubble map for the number of listings for each region and use find the average price for
#bedrooms and the overal average price using the dataframes
