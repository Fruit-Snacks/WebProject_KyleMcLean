# %%
import pandas as pd

filename ='Users\Owner\PycharmProjects\CSC3130\WebProject_KyleMcLean\Briefs\2017-02-18CraigslistBriefs.json'
#filename = 'C:\Users\username\pathToFile\fileName.json'
#filename = 'fileName.json'
data = pd.read_json('2017-02-18CraigslistBriefs.json')

# %%
data
# Out:
#                                               location           phone  \
# 0                                          (Nashville)             NaN
# 1                                     (Hendersonville)             NaN
# 2                                           Not listed             NaN
# 3                     (Nashville,West End, Vanderbilt)             NaN
# 4                 (1650 Cason, Murfreesboro, TN 37128)             NaN
# 5                       (3525 West End Ave, Nashville)             NaN
# 6                                      (nashville, tn)             NaN
# 7                                           Not listed             NaN
# 8                                           Not listed             NaN
# 9                                           Not listed             NaN
# 10                                          Not listed             NaN
# 11                                          Not listed             NaN
# ...

# %%
pd.set_option('display.height', 800)
pd.set_option('display.max_rows', 800)
# Out:
# height has been deprecated.

# %%
data
# Out:
#                                               location           phone  \
# 0                                          (Nashville)             NaN
# 1                                     (Hendersonville)             NaN
# 2                                           Not listed             NaN
# 3                     (Nashville,West End, Vanderbilt)             NaN
# 4                 (1650 Cason, Murfreesboro, TN 37128)             NaN
# 5                       (3525 West End Ave, Nashville)             NaN
# 6                                      (nashville, tn)             NaN
# 7                                           Not listed             NaN
# 8                                           Not listed             NaN
# 9                                           Not listed             NaN
# 10                                          Not listed             NaN
# 11                                          Not listed             NaN
# ...

# %%
data.sort_values('size')
# Out:
#                                               location           phone  \
# 100                               (Downtown Nashville)  (844) 538-9754
# 274                                    (West End Park)  (844) 711-6208
# 270                               (Downtown Nashville)  (844) 538-9754
# 410                               (Downtown Nashville)  (844) 538-9754
# 413                               (Bellmont-Hillsboro)  (844) 310-7996
# 416                                    (West End Park)  (844) 711-6208
# 418                                      (Green Hills)  (888) 923-3149
# 430                               (Downtown Nashville)  (844) 538-9754
# 432                               (Bellmont-Hillsboro)  (844) 310-7996
# 438                                      (Green Hills)  (888) 923-3149
# 450                               (Downtown Nashville)  (844) 538-9754
# 452                               (Bellmont-Hillsboro)  (844) 310-7996
# ...

# %%
data.isnull()
# Out:
#     location  phone  price   size
# 0      False   True  False   True
# 1      False   True  False   True
# 2      False   True  False   True
# 3      False   True  False   True
# 4      False   True  False   True
# 5      False   True  False   True
# 6      False   True  False   True
# 7      False   True  False   True
# 8      False   True  False   True
# 9      False   True  False   True
# 10     False   True  False   True
# 11     False   True  False   True
# 12     False   True  False   True
# 13     False   True  False   True
# 14     False   True  False   True
# 15     False   True  False   True
# 16     False   True  False   True
# 17     False   True  False   True
# 18     False   True  False   True
# 19     False   True  False   True
# 20     False   True  False   True
# 21     False   True  False   True
# 22     False   True  False   True
# 23     False   True  False   True
# 24     False   True  False   True
# 25     False   True  False   True
# ...

# %%
data.sort_values('size').isnull()
# Out:
#     location  phone  price   size
# 100    False  False  False  False
# 274    False  False  False  False
# 270    False  False  False  False
# 410    False  False  False  False
# 413    False  False  False  False
# 416    False  False  False  False
# 418    False  False  False  False
# 430    False  False  False  False
# 432    False  False  False  False
# 438    False  False  False  False
# 450    False  False  False  False
# 452    False  False  False  False
# 455    False  False  False  False
# 458    False  False  False  False
# 470    False  False  False  False
# 473    False  False  False  False
# 477    False  False  False  False
# 480    False  False  False  False
# 490    False  False  False  False
# 493    False  False  False  False
# 276    False  False  False  False
# 398    False  False  False  False
# 396    False  False  False  False
# 290    False  False  False  False
# 350    False  False  False  False
# 356    False  False  False  False
# ...

# %%
pd.set_option('display.height', 850)
pd.set_option('display.max_rows', 850)
# Out:
# height has been deprecated.

# %%
data.sort_values('size').isnull()
# Out:
#     location  phone  price   size
# 100    False  False  False  False
# 274    False  False  False  False
# 270    False  False  False  False
# 410    False  False  False  False
# 413    False  False  False  False
# 416    False  False  False  False
# 418    False  False  False  False
# 430    False  False  False  False
# 432    False  False  False  False
# 438    False  False  False  False
# 450    False  False  False  False
# 452    False  False  False  False
# 455    False  False  False  False
# 458    False  False  False  False
# 470    False  False  False  False
# 473    False  False  False  False
# 477    False  False  False  False
# 480    False  False  False  False
# 490    False  False  False  False
# 493    False  False  False  False
# 276    False  False  False  False
# 398    False  False  False  False
# 396    False  False  False  False
# 290    False  False  False  False
# 350    False  False  False  False
# 356    False  False  False  False
# ...

# %%
data["price"].dropna()
# Out:
# 0                $1525
# 1                 $859
# 2                 $829
# 3           Not listed
# 4                $1160
# 5                $1650
# 6                 $831
# 7                 $900
# 8                $1100
# 9                $1175
# 10               $1016
# 11                $675
# 12                $795
# 13                $975
# 14                $775
# 15               $1306
# 16               $1249
# 17               $1200
# 18               $1010
# 19               $1633
# 20               $1205
# 21               $1175
# 22                $978
# 23               $1249
# 24               $1815
# 25                $430
# 26          Not listed
# 27               $1149
# 28               $1995
# 29                $829
# 30               $1068
# 31                $800
# 32                $965
# 33                $965
# 34                $834
# 35               $1366
# 36               $1249
# 37               $1125
# 38                $965
# 39               $1425
# ...

# %%
data
# Out:
#                                               location           phone  \
# 0                                          (Nashville)             NaN
# 1                                     (Hendersonville)             NaN
# 2                                           Not listed             NaN
# 3                     (Nashville,West End, Vanderbilt)             NaN
# 4                 (1650 Cason, Murfreesboro, TN 37128)             NaN
# 5                       (3525 West End Ave, Nashville)             NaN
# 6                                      (nashville, tn)             NaN
# 7                                           Not listed             NaN
# 8                                           Not listed             NaN
# 9                                           Not listed             NaN
# 10                                          Not listed             NaN
# 11                                          Not listed             NaN
# ...

# %%
data.sort_values('size')
# Out:
#                                               location           phone  \
# 100                               (Downtown Nashville)  (844) 538-9754
# 274                                    (West End Park)  (844) 711-6208
# 270                               (Downtown Nashville)  (844) 538-9754
# 410                               (Downtown Nashville)  (844) 538-9754
# 413                               (Bellmont-Hillsboro)  (844) 310-7996
# 416                                    (West End Park)  (844) 711-6208
# 418                                      (Green Hills)  (888) 923-3149
# 430                               (Downtown Nashville)  (844) 538-9754
# 432                               (Bellmont-Hillsboro)  (844) 310-7996
# 438                                      (Green Hills)  (888) 923-3149
# 450                               (Downtown Nashville)  (844) 538-9754
# 452                               (Bellmont-Hillsboro)  (844) 310-7996
# ...

# %%
data["size"].dropna()
# Out:
# 100                 1 Bed
# 101                2 Beds
# 102                2 Beds
# 103                2 Beds
# 104                 1 Bed
# 105                 1 Bed
# 106                3 Beds
# 107                4 Beds
# 108                3 Beds
# 109                3 Beds
# 110                3 Beds
# 111                3 Beds
# 112                2 Beds
# 113                3 Beds
# 114                3 Beds
# 115                3 Beds
# 116                2 Beds
# 117                2 Beds
# 118                3 Beds
# 119                3 Beds
# 120            Not listed
# 121            Not listed
# 122            Not listed
# 123            Not listed
# 124                   3br
# 125            Not listed
# 126            Not listed
# 127            Not listed
# 128            Not listed
# 129            Not listed
# 130            Not listed
# 131            Not listed
# 132                   1br
# 133            Not listed
# 134            Not listed
# ...

# %%
data.sort_values('size')
# Out:
#                                               location           phone  \
# 100                               (Downtown Nashville)  (844) 538-9754
# 274                                    (West End Park)  (844) 711-6208
# 270                               (Downtown Nashville)  (844) 538-9754
# 410                               (Downtown Nashville)  (844) 538-9754
# 413                               (Bellmont-Hillsboro)  (844) 310-7996
# 416                                    (West End Park)  (844) 711-6208
# 418                                      (Green Hills)  (888) 923-3149
# 430                               (Downtown Nashville)  (844) 538-9754
# 432                               (Bellmont-Hillsboro)  (844) 310-7996
# 438                                      (Green Hills)  (888) 923-3149
# 450                               (Downtown Nashville)  (844) 538-9754
# 452                               (Bellmont-Hillsboro)  (844) 310-7996
# ...
